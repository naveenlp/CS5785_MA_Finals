# %%
# read in data and store in variables
from PIL import Image
im = Image.open("./images/parrots.jpg")
print(im.format, im.size, im.mode)
rgb_im = im.convert('RGB')
rgb = rgb_im.getpixel((210, 120))
print rgb
size = 200,180
imt = im.convert('RGB')
imt.thumbnail(size, Image.ANTIALIAS)
imt
# Out:
# ('JPEG', (800, 640), 'RGB')
# (205, 90, 83)
# <PIL.Image.Image image mode=RGB size=200x160 at 0x1049C8758>

# %% [markdown]
# ####3b. Preprocessing the input. To build your “training set,” uniformly sample 5,000 random (x, y) coordinate locations.
# ####• What other preprocessing steps are necessary for random forests inputs? Describe them, implement them, and justify your decisions. In particular, do you need to perform mean subtraction, standardization, or unit-normalization?
# The input was preprocessed and 5000 random sample coordinate locations were selected as training data.
#
# No other preprocessing steps are necessary for random forest inputs as the decision tree can easily handle decision splits at any real number values. In fact, this lack of necessity to preprocess the inputs is one of the main attractions for using the Random Forest algorithm. Hence, we choose not to apply any preprocessing steps to the sampled training data.
#
# ####3c. Preprocessing the output. Sample pixel values at each of the given coordinate locations. Each pixel contains red, green, and blue intensity values, so decide how you want to handle this. There are several options available to you:
# ####• Convert the image to grayscale
# ####• Regress all three values at once, so your function maps (x, y) coordinates to (r, g ,b) values:
# ####f : R^2 → R^3
# ####• Learn a different function for each channel, fRed : R2 → R, and likewise for fGreen, fBlue
#
# We choose the 3rd option. We learn different functions for each channel
#
# #### 3d. Rescale the pixel intensities to lie between 0.0 and 1.0. (The default for pixel values may be between 0 and 255, but your image library may have different defaults.)
#
# We avoid this step as it is not required as per discussion on piazza
#
# ####3e. What other preprocessing steps are necessary for random regression forest outputs? Describe them, implement them, and justify your decisions.
#
# No other preprocessing steps are necessary for random regression forest outputs and we do not implement any additional steps

# %%
# get combinations of x y coordinates depending on size of image
import itertools
import numpy as np
import random

list1, list2 = np.arange(im.size[0]), np.arange(im.size[1])
combinations = np.array(list(itertools.product(list1, list2)))
combinations
# Out:
# array([[  0,   0],
#        [  0,   1],
#        [  0,   2],
#        ...,
#        [799, 637],
#        [799, 638],
#        [799, 639]])

# %%
# obtain training inputs and r,g,b labels
# https://www.quora.com/What-is-setting-random-forests-apart-from-other-ensemble-methods-in-Data-Science
def get_train_and_outputs(combinations, rgb_im, count = 5000):
    train_inputs = np.array(random.sample(combinations, count))
    rs, gs, bs = [], [], []
    for idx,ti in enumerate(train_inputs):
        r,g,b = list(rgb_im.getpixel((ti[0], ti[1])))
        rs.append(r)
        gs.append(g)
        bs.append(b)
    
    return train_inputs, rs, gs, bs

# test
train_inputs, rs, gs, bs = get_train_and_outputs(combinations, rgb_im)
print train_inputs[0:5]
print "\n"
print rs[0:5],"\n",gs[0:5],"\n",bs[0:5]
# Out:
# [[455 336]
#  [495 322]
#  [735 545]
#  [107 190]
#  [248 586]]
#
#
# [149, 36, 71, 88, 137]
# [136, 106, 155, 84, 138]
# [81, 131, 219, 83, 133]

# %% [markdown]
# ####3f. To build the final image, for each pixel of the output, feed the pixel coordinate through the random forest and color the resulting pixel with the output prediction. You can then use imshow to view the result. (If you are using grayscale, try imshow(Y, cmap=’gray’) to avoid fake-coloring). You may use any implementation of random forests, but you should understand the implementation and you must cite your sources.
# We use scikit-learn implementation of the random regression forest algorithm and fit it with the training data and predict the output for r, g and b channels. Then we reconstruct the image and display it using imshow. We display the output with default settings

# %%
# get random forest rgbs
from sklearn.ensemble import RandomForestRegressor 

def get_rgbs_for(combinations, train_inputs, rs, gs, bs, n_trees = 1, n_depth = 7, min_leaf_size = 1, min_split_size = 2, min_wt_fr_leaf = 0):
    
    def get_rfr():
        return RandomForestRegressor(n_estimators = n_trees, max_depth = n_depth, min_samples_leaf = min_leaf_size, min_samples_split = min_split_size)
    
    # train random forest classifiers for r, g and b
    output_r = get_rfr().fit(train_inputs,rs).predict(combinations)
    output_g = get_rfr().fit(train_inputs,gs).predict(combinations)
    output_b = get_rfr().fit(train_inputs,bs).predict(combinations)
    
    return output_r, output_g, output_b

# test
output_r, output_g, output_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs)

# %%
# reconstitute image
from matplotlib import pyplot as plt
# %matplotlib inline

def display_image(combinations, output_r, output_g, output_b, imsize):
    # rgb array used to display image
    data = np.zeros( (imsize[1],imsize[0],3), dtype=np.uint8)

    for idx, xy in enumerate(combinations):
        data[xy[1], xy[0]] = [int(output_r[idx]),int(output_g[idx]),int(output_b[idx])]

    plt.imshow(data, interpolation='nearest')
    plt.show()
    
# test
display_image(combinations, output_r, output_g, output_b, im.size)

# %% [markdown]
# # 3g. EXPERIMENTATION

# %% [markdown]
# ####(a) Repeat the experiment for a random forest containing a single decision tree, but with depths 1, 2, 3, 5, 10, and 15. How does depth impact the result? Describe in detail why.
#
# We use a single decision tree and tree depths are chosen from [1, 2, 3, 5, 10, 15] and the results are displayed.
#
# It is observed that the tree depth clearly impacts the results. The reason is, as we increase the tree depth, the number of possible colors and the number of split points increases. This allows for more fine tuned split points and color values and consequently, the result has a noticeably higher degree of accuracy with increasing depth

# %%
# display random forest results for different depths
depths = [1, 2, 3, 5, 10, 15]

for d in depths:
    o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, n_depth = d)
    print "DEPTH:", d
    display_image(combinations, o_r, o_g, o_b, im.size)
# Out:
# DEPTH: 1
# DEPTH: 2
# DEPTH: 3
# DEPTH: 5
# DEPTH: 10
# DEPTH: 15

# %% [markdown]
# ####(b) Repeat the experiment for a random forest of depth 7, but with number of trees equal to 1, 3, 5, 10, and 100. How does the number of trees impact the result? Describe in detail why.
#
# We vary the number of trees with values chosen from [1, 2, 3, 5, 10, 15]. We use a constant tree depth of 7. The regression results are displayed.
#
# It is observed that increasing the tree depth has only a minimal impact on the quality of the result. The quality of the result doesn't increase much beyond 5 trees. This could possibly be because a tree depth of 7 is sufficiently large to analyze the input image well. For around 5 trees, the impact of averaging does contribute to reducing the variance in the regression result. But beyond that, the variance does not reduce significantly any further.

# %%
# vary number of trees
tree_counts = [1, 3, 5, 10, 100]

for nt in tree_counts:
    o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, n_trees = nt)
    print "NUMBER OF TREES:", nt
    display_image(combinations, o_r, o_g, o_b, im.size)
# Out:
# NUMBER OF TREES: 1
# NUMBER OF TREES: 3
# NUMBER OF TREES: 5
# NUMBER OF TREES: 10
# NUMBER OF TREES: 100

# %% [markdown]
# ####(c) As a simple baseline, repeat the experiment using a k-NN regressor, for k = 1. This means that every pixel in the output will equal the nearest pixel from the “training set.” Compare and contrast the outlook: why does this look the way it does?
#
# We get a visually better quality result with k-NN regressor. Also, the image appears splotchy. This is expected as every input point gets mapped to it's nearest neighbour in the 5000 training data points (as we choose k = 1). So, this is like the colors condense around the 5000 training points, leading to the splotchiness.
#
# In contrast, the image from the random forest regression has patches that are rectangular in shape. This is also expected because each color is a regression value on a treemap in the case of 1 tree. Multiple trees are like superimposed treemaps and will also lead to similar results.

# %%
# use knn regression
from sklearn import neighbors

knn = neighbors.KNeighborsRegressor(1)
o_r_knn = knn.fit(train_inputs,rs).predict(combinations)
o_g_knn = knn.fit(train_inputs,gs).predict(combinations)
o_b_knn = knn.fit(train_inputs,bs).predict(combinations)
display_image(combinations, o_r_knn, o_g_knn, o_b_knn, im.size)

# %% [markdown]
# ###(d) Experiment with different pruning strategies of your choice.
#
# We first try to obtain optimal results by varying the number of trees and depth. We finally pick N(trees) as 20 and depth of trees as 20. Using a good quality base image will help us determine the loss in quality of pruned trees.
#
# For pruning, we vary the minimum leaf size and the minimum split size. These parameters are supported by the scikit-learn random regression forest implementation. After running simulations, we determine that the following parameter values produce a result of acceptable quality (visually)
#
# min_split_size = 4, min_leaf_size = 3

# %%
# experimental: try to obtain better results by increasing number of trees
o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, n_trees = 20, n_depth = 20)
display_image(combinations, o_r, o_g, o_b, im.size)

# %%
# experimental: vary minimum leaf size
for i in np.arange(1, 6):
    o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, min_leaf_size = i, n_trees = 20, n_depth = 20)
    print "MINIMUM LEAF SIZE:", i
    display_image(combinations, o_r, o_g, o_b, im.size)
# Out:
# MINIMUM LEAF SIZE: 1
# MINIMUM LEAF SIZE: 2
# MINIMUM LEAF SIZE: 3
# MINIMUM LEAF SIZE: 4
# MINIMUM LEAF SIZE: 5

# %%
# experimental: vary minimum split size
for i in np.arange(2, 7):
    o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, min_split_size = i, n_trees = 20, n_depth = 20)
    print "MINIMUM SPLIT SIZE:", i
    display_image(combinations, o_r, o_g, o_b, im.size)
# Out:
# MINIMUM SPLIT SIZE: 2
# MINIMUM SPLIT SIZE: 3
# MINIMUM SPLIT SIZE: 4
# MINIMUM SPLIT SIZE: 5
# MINIMUM SPLIT SIZE: 6

# %%
# experimental: pruned tree
o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, min_split_size = 4, min_leaf_size = 3, n_trees = 15, n_depth = 20)
display_image(combinations, o_r, o_g, o_b, im.size)

# %% [markdown]
# #3h. ANALYSIS

# %% [markdown]
# ####(a) What is the decision rule at each split point? Write down the 1-line formula for the split point at the root node for one the trained decision trees inside the forest. Feel free to define any variables you need.
#
# Each split point occurs either on the X-axis or on the Y-axis. Let's assume the root node split point is on the X-axis. If the input point's x value is less than the split point, it goes down the left of the decision tree, and if it is greater, then it goes to the right of the decision tree.
#
# We get the split points using the code in the cell below. We determine that the 1-line formula for the root node is:
#
# X[1] <= 54.5000
#
# Here, X[0] represents the X coordinate and X[1] represents the Y coordinate. So, in the formula above, if the Y coordinate is less than 54.5, the input point descends down the left branch of the tree.

# %%
from sklearn import tree

test_regressor = RandomForestRegressor(n_estimators = 2, max_depth = 7).fit(train_inputs,rs)
test_dt = test_regressor.estimators_[0]

my_file = tree.export_graphviz(test_dt.tree_, out_file = "output_decision_tree")

# %% [markdown]
# ####(b) Why does the resulting image look like the way it does? What shape are the patches of color, and how are they arranged?
# The shape of the patches of color are rectangular and they are arranged in an interlocking rectangular pattern.
#
# This is expected because each color is a regression value on a treemap in the case of 1 tree. Multiple trees are like superimposed treemaps and will also lead to similar results.

# %% [markdown]
# ####(c) Easy: How many patches of color may be in the resulting image if the forest contains a single decision tree? Define any variables you need.
#
# The number of patches of color may be defined in several ways. Assuming there is only one tree of depth d, an upper limit on the number of patches can easily be determined as 2^d. This is observed in the simulation below where for 1 tree, the number of colours closely correspond to 2^d until around d = 5. A strict upper bound for each channel is 256 however. So the upper bound is min(2^d, 256)
#
# Alternatively, if we know the number of leaves in the decision tree (l), then the number of patches of color in the resulting image has an upper bound of min(count(l), 256) for each channel.

# %%
# get number of colors for n_depth = 1 to 7
for i in np.arange(1, 8):
    o_r, o_g, o_b = get_rgbs_for(combinations, train_inputs, rs, gs, bs, n_trees = 1, n_depth = i)
    o_r = [int(x) for x in o_r]
    o_g = [int(x) for x in o_g]
    o_b = [int(x) for x in o_b]
    rcount, gcount, bcount = len(set(o_r)), len(set(o_g)), len(set(o_b))
    print "depth:", i, "reds:", rcount, "greens:", gcount, "blues:", bcount
# Out:
# depth: 1 reds: 2 greens: 2 blues: 2
# depth: 2 reds: 4 greens: 4 blues: 4
# depth: 3 reds: 7 greens: 8 blues: 8
# depth: 4 reds: 15 greens: 14 blues: 16
# depth: 5 reds: 28 greens: 31 blues: 32
# depth: 6 reds: 45 greens: 56 blues: 54
# depth: 7 reds: 80 greens: 94 blues: 89

# %% [markdown]
# ####(d) Tricky: How many patches of color might be in the resulting image if the forest contains n decision trees? Define any variables you need.
#
# If we have more than 1 decision tree, the number of colors is harder to determine as the values of different trees are averaged to arrive at the regression output.
#
# There are ways to determine an upperbound however. We first need to determine the split points of all the decision trees for the X and Y axis. Let's call this nx and ny respectively. Then, we can multiply the count of nx and ny respectively to get an upperbound. However, if this value exceeds 256, we limit the number of possible outputs to 256 for each channel.
#
# So, the upper bound is min(nx\*ny, 256) for each channel
